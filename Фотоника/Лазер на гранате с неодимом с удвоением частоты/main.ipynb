# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=  pd.read_csv('kpd.csv')

plt.scatter(data['I[A]'], data['P[Wt]'])
plt.xlabel("Сила тока")
plt.ylabel("мощность")
# Out:
# Text(0, 0.5, 'мощность')

# %%
data=pd.read_csv("power_of_second_harmonics_by_pumping_power.csv")
plt.scatter(data['P_lazer[Wt]'], data['U[V]'])

# %%
data = pd.read_csv('power_by_angle.csv')

plt.scatter(-data['angle'], data['power'])
